# %%
from pyspark.sql.functions import upper,initcap
from pyspark.sql.types import *

# %% [markdown]
# # STRING

# %%
data = [("Manikandan"),("JoHn"),("SanKar"),("CHOTTABHEEM"),("ben10")]

df = spark.createDataFrame(data, ["name"])
df.show()

# %%
df = df.withColumn("name", initcap("name"))
df.show()
