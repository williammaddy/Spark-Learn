# %%
from pyspark.sql.types import *

# %%
schema = StructType([
    StructField('city', StringType(), True), 
    StructField('department', StringType(), True), 
    StructField('emp_id', LongType(), True), 
    StructField('name', StringType(), True), 
    StructField('salary', LongType(), True)])

# %%
df_json = spark.readStream.format("json")\
    .option("multiLine",True)\
    .schema(schema)\
    .load("/Volumes/sparkcatalog/raw/source/json/Append/Day1.json")

# %%
print(df_json.isStreaming)

# %%
query = (
    df_json.writeStream
          .format("delta")
          .outputMode("append")
          .trigger(availableNow=True)
          .option("checkpointLocation", "/Volumes/sparkcatalog/raw/source/json/sink_append/checkpoint")
          .option("path", "/Volumes/sparkcatalog/raw/source/json/sink_append/data")
          .start()
)

query.awaitTermination()

# %%
df_json.writeStream.format("delta")\
    .outputMode("append")\
    .trigger(availableNow=True)\
    .option("checkpointLocation","/Volumes/sparkcatalog/raw/source/json/sink_append/checkpoint")\
    .option("path","/Volumes/sparkcatalog/raw/source/json/sink_append/data")\
    .start()
